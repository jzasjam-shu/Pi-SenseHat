# %% [markdown]
# # Raspberry Pi: Using GPIO Pins

# %% [markdown]
# ---
#
# ## Light Dependent Resistor (LDR): Light Level Detection
#
# <img width="400" alt="image" src="../images/LDR_bb.png" style="float: right;" />
# <img width="150" alt="image" src="../images/pi-gpio-pinout.png" style="float: right;" />
#
# ### Wiring Instructions
#
# **LDR**
# - Can be placed either way around
#
# **Capacitor**
#   - Positive side (long leg) should be in the same breadboard column as the LDR leg
#
# **Jumper Wires (M/F)**
# - Black (in the example, use any colour)
#     -  Goes to GND (Pin 6 on the Raspberry Pi)
# - Red
#     - Goes to 3V3 (Pin 17 on the Raspberry Pi)
# - Blue
#     - Goes to GPIO18 (Pin 19 on the Raspberry Pi)
#
# **Pins Reference**
#
# Hint: Use command `pinout` in the Raspberry Pi terminal to view the GPIO pin information

# %% [markdown]
# ### Prerequisite: Enable I2C for GPIO Pins Access
#
# 1. On the Raspberry Pi, click the ‘Raspberry Pi Menu’ button, then select ‘Preferences’ and ‘Raspberry Pi Configuration’
#
# <img width="400" alt="image" src="../images/config.png" />
#
# 2. In the Raspberry Pi Configuration window select the ‘Interfaces’ tab, then toggle I2C so that it is enabled and click ‘OK’
#
# <img width="400" alt="image" src="../images/i2c.png" />
#
# 3. You may be required to reboot the Pi if you have made changes

# %%
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# GET THE LDR (Light Dependant Resistor) LIGHT SENSOR VALUE
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# Source: Modified from https://gpiozero.readthedocs.io/en/latest/recipes.html#light-sensor 

from gpiozero import LightSensor
import time

sensor = LightSensor(18)

# Continuously detect light level
print("Press Ctrl+C To Stop")

while True:
	time.sleep(0.1) # Small delay between readings
	print(sensor.value)

# %%
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# GET THE LDR (Light Dependant Resistor) LIGHT EVENTS
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #

from gpiozero import LightSensor

sensor = LightSensor(18)

# Detect when it is light or dark
print("Press Ctrl+C To Stop")

while True:
	sensor.wait_for_light()
	print("It's light! :)") # Print a notification
	print(sensor.value)	# Print the value (between 0-1)
	
	sensor.wait_for_dark()
	print("It's dark :(")
	print(sensor.value)

# %% [markdown]
# ## Troubleshooting
#
# ### No I2C device at address: 0x38
#
# If you receive errors when running the Python code regarding ‘ValueError: No I2C device at address: 0x38’, this means the sensor has not been recognised or connected correctly. The sensor has a green LED which should light up when the sensor is connected correctly.
#
# **Check I2C Connections**
#
# 1. Install I2C Tools:
#    `sudo apt install -y i2c-tools`
#
# 2. Use the following to check the input addresses:
#    `i2cdetect -y 1`
#
# If the sensor is connected successfully, the results should look similar to the image with an entry at an address
#
# <img width="400" alt="image" src="../images/i2c-test.png" />
